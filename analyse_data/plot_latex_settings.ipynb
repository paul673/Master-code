# %%
import matplotlib.font_manager
matplotlib.font_manager.findSystemFonts(fontpaths=None, fontext='ttf')
# Out:
# ['C:\\Windows\\Fonts\\DejaVuSansMono-Bold.ttf',
#  'C:\\Windows\\Fonts\\segoeuisl.ttf',
#  'C:\\Windows\\Fonts\\segoeprb.ttf',
#  'C:\\Windows\\Fonts\\GeorgiaPro-CondItalic.ttf',
#  'C:\\Windows\\Fonts\\RockwellNovaCond-BoldItalic.ttf',
#  'C:\\Windows\\Fonts\\GeorgiaPro-SemiBoldItalic.ttf',
#  'C:\\Windows\\Fonts\\ArialNova-LightItalic.ttf',
#  'C:\\Windows\\Fonts\\cambriaz.ttf',
#  'C:\\Windows\\Fonts\\GeorgiaPro-CondLightItalic.ttf',
#  'C:\\Windows\\Fonts\\constan.ttf',
#  'C:\\Windows\\Fonts\\ESSTIX4_.TTF',
#  'C:\\Windows\\Fonts\\DejaVuSans-BoldOblique.ttf',
#  'C:\\Windows\\Fonts\\ArialNova.ttf',
#  'C:\\Windows\\Fonts\\consolaz.ttf',
#  'C:\\Windows\\Fonts\\GillSansCondNova.ttf',
#  'C:\\Windows\\Fonts\\calibriz.ttf',
#  'C:\\Windows\\Fonts\\NirmalaB.ttf',
#  'C:\\Windows\\Fonts\\DejaVuSansCondensed-Oblique.ttf',
#  'C:\\Windows\\Fonts\\phagspab.ttf',
#  'C:\\Windows\\Fonts\\ariali.ttf',
#  'C:\\Windows\\Fonts\\DejaVuSerif-Italic.ttf',
# ...

# %%
from matplotlib import font_manager as fm
# Path to the TTF file
font_path = r"C:\Users\paulj\AppData\Local\Microsoft\Windows\Fonts\cmunrm.ttf"

# Create a font object
cmu_font = fm.FontProperties(fname=font_path)

fm.fontManager.addfont(font_path)
cmu_font.get_name()
# Out:
# 'CMU Serif'

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
from cycler import cycler

# %%
from cycler import cycler
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# Use LaTeX for all text rendering
mpl.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",           
    "font.serif": ["Computer Modern Roman"],
    "font.size": 12,                  
    "axes.titlesize": 12,
    "axes.labelsize": 12,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "legend.fontsize": 12,
})

# Set default colors to searborn deep
deep_colors = sns.color_palette("deep")
plt.rcParams['axes.prop_cycle'] = cycler(color=deep_colors) 

# Calculate default figure sizes
doc_width = 8.27 # A4 width
lmargin = 1.5 # Left margin
rmargin = 1 # Right margin
plot_width = doc_width-lmargin-rmargin # Compute document width
plot_height = plot_width* (5**0.5 - 1) / 2 # Golden ratio for height

# %%
from cycler import cycler
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
from matplotlib import font_manager as fm

# Load Modern Computer Roman Font
font_path = r"C:\Users\paulj\AppData\Local\Microsoft\Windows\Fonts\cmunrm.ttf"
cmu_font = fm.FontProperties(fname=font_path)
fm.fontManager.addfont(font_path)

# Use LaTeX for all text rendering
mpl.rcParams.update({
    "font.family": 'CMU Serif',  
    "font.size": 12, 
})

# Set default colors to searborn deep
deep_colors = sns.color_palette("deep")
plt.rcParams['axes.prop_cycle'] = cycler(color=deep_colors) 

# Calculate default figure sizes
doc_width = 8.27 # A4 width
lmargin = 1.5 # Left margin
rmargin = 1 # Right margin
plot_width = doc_width-lmargin-rmargin # Compute document width
plot_height = plot_width* (5**0.5 - 1) / 2 # Golden ratio for height

# %%
doc_width = 8.27
lmargin = 1.5
rmargin = 1
width = doc_width-lmargin-rmargin

height =width* (5**0.5 - 1) / 2

# %%
import numpy as np

# %%
x =np.linspace(-1,3)

# %%
import matplotlib.font_manager as fm

available_fonts = [f.name for f in fm.fontManager.ttflist]
print("CMU Serif" in available_fonts)  # Should print True
# Out:
# True

# %%
plt.plot(x,x**2)
plt.title("hei ")
# Out:
# Text(0.5, 1.0, 'hei ')

# %%
fig = plt.figure(figsize=(width,height))
plt.plot(x,x**2)
