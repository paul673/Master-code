# %%
import pandas as pd

import numpy as np
from rdkit import Chem
import torch
from torch.utils.data import Dataset

# %%
from pom_models.functions import fragance_propabilities_from_smiles

from numpy.linalg import norm

TARGET_SMILES = "COC1=C(C=CC(=C1)C=O)O"
TARGET_VEC = fragance_propabilities_from_smiles(TARGET_SMILES)[0]

# %%
# MCF imports
from molecule_validation import is_odorant, score_molecule

# %%
def calculate_score(mol, is_vanilla):
    # Odorant filter + All MCF Filters + Has vanilla scent / 3 (To calculate mean of these params)
    return (is_odorant(mol)[0] + score_molecule(mol).all() + is_vanilla)/3

def calculate_score_online(mol):
    # Odorant filter + All MCF Filters + Has vanilla scent / 3 (To calculate mean of these params)
    return int(is_odorant(mol)[0]) + score_molecule(mol).all()

def hard_filter(mol):
    return int(is_odorant(mol)[0]) * score_molecule(mol).all()

# %% [markdown]
# ### Define dataset

# %%
class OpenPOMDataset(Dataset):
    def __init__(self, openpom_file="openpomdata.csv", train=True, split_seed=142857, ratio=0.9):
        df = pd.read_csv(openpom_file).drop("descriptors",axis=1)
        df =  df[df['odorless'] == False]
        df = df[df["nonStereoSMILES"].apply(self.explicit_H_filter)].copy()  
        df = df.reset_index(drop=True)

        # Scent corrolation 
        scent_matrix = df[df.keys()[1:]].to_numpy()

        vanilla_idx = list(df.keys()[1:]).index("vanilla")  

        # compute Pearson correlation between vanilla and every other scent
        vanilla_col = scent_matrix[:, vanilla_idx]
        corrs = np.array([np.corrcoef(vanilla_col, scent_matrix[:, i])[0,1] for i in range(138)])
        vanilla_corr_vec = np.nan_to_num(corrs)  # shape: (138,), with NaNs replaced by 0


        scent_cols = df.columns[1:]
        df["reward"]= df[scent_cols].apply(lambda x: self.cosine_similarity(x, vanilla_corr_vec), axis=1)

        # Normalize to [0.1, 1.0] range (or any positive range you like)
        min_r = df["reward"].min()
        max_r = df["reward"].max()

        # Avoid zero reward
        scaled_rewards = 0.1 + 0.9 * (df["reward"] - min_r) / (max_r - min_r)
        df["shift_reward"] = scaled_rewards


        #df = self.generate_scores(df)
        self.df = df
        rng = np.random.default_rng(split_seed)
        idcs = np.arange(len(self.df))
        rng.shuffle(idcs)
        if train:
            self.idcs = idcs[: int(np.floor(ratio * len(self.df)))]
        else:
            self.idcs = idcs[int(np.floor(ratio * len(self.df))) :]
        self.obj_to_graph = lambda x: x
        self.targets = self.df.keys()[1:]

    def setup(self, task, ctx):
        self.obj_to_graph = ctx.obj_to_graph


    def __len__(self):
        return len(self.idcs)

    def __getitem__(self, idx):
        # Returns the RDkit mol object and corresponding 138 scent labels
        m_smiles = self.df["nonStereoSMILES"][self.idcs[idx]]
        return (
            self.obj_to_graph(Chem.MolFromSmiles(m_smiles)),
            #torch.tensor([self.df[t][self.idcs[idx]] for t in self.targets]).float(),
            #torch.tensor([0.5 if self.df['vanilla'][self.idcs[idx]] == 0 else 1]).float(), # 0.5 reward for non vanilla molecues 1 for vanilla molecules
            #torch.tensor([self.compute_reward_from_smiles(m_smiles)]).float()
            #torch.tensor([self.df['score'][self.idcs[idx]]]).float(),
            torch.tensor([self.df['shift_reward'][self.idcs[idx]]]).float(),
        )
    
    def compute_reward_from_smiles(self, m_smiles):
            m_vec = fragance_propabilities_from_smiles(m_smiles)[0]
            return self.cosine_similarity(TARGET_VEC,m_vec)
    
    def cosine_similarity(self,vec1,vec2):
        return np.dot(vec1,vec2)/(norm(vec1)*norm(vec2))
    
    def explicit_H_filter(self, smiles: str) -> bool:
        mol = Chem.MolFromSmiles(smiles)
        for atom in mol.GetAtoms():
            if atom.GetNumExplicitHs() > 1:
                return False  
        return True
    

    
    def generate_scores(self, df):
        df['score'] = df.apply(
            lambda x: calculate_score(
                Chem.MolFromSmiles(x.nonStereoSMILES), 
                x.vanilla
                ), axis=1)
        return df

# %%
from gflownet import GFNTask,LogScalar,ObjectProperties
from gflownet.config import Config,init_empty
from typing import Dict, List, Tuple
from torch import Tensor

# %%
class ScentTask(GFNTask):
    def __init__(self, dataset: Dataset, cfg: Config):
        self.dataset = dataset
        self.num_cond_dim = 1
        self.num_objectives = 138

    def sample_conditional_information(self, n: int, train_it: int) -> Dict[str, Tensor]:
        return {"encoding": torch.ones(n, 1)}

    def cond_info_to_logreward(self, cond_info: Dict[str, Tensor], obj_props: ObjectProperties) -> LogScalar:
        #print(obj_props)
        scalar_logreward = torch.as_tensor(obj_props).squeeze().clamp(min=1e-30).log()
        #print(scalar_logreward)
        return LogScalar(scalar_logreward.flatten())
    
    def compute_obj_properties(self, mols):
        is_valid = torch.tensor([m.GetNumAtoms() > 1 and Chem.Descriptors.NumRadicalElectrons(m) == 0 for m in mols ]).to(torch.bool)#.bool()
        if not is_valid.any():
            return ObjectProperties(torch.zeros((0,1))), is_valid
        valid_mols = [mol for mol, valid in zip(mols, is_valid) if valid]
        #scores = torch.tensor([calculate_score_online(m) for m in valid_mols])
        rs = torch.tensor(self.compute_reward_from_mols(valid_mols))
        #rs = (rewards+scores) /3
        return ObjectProperties(rs.reshape((-1, 1))), is_valid 
    
        #Attempt for multible scents
        #flat_r = []
        #for m in mols:
        #    flat_r.append(torch.tensor(fragance_propabilities_from_smiles(Chem.MolToSmiles(m))[0]).float())
        #flat_rewards = torch.stack(flat_r, dim=0)
        #return ObjectProperties(flat_rewards), is_valid
    
    def compute_reward_from_mols(self, mols):
        rewards = []
        for m in mols:
            m_smiles = Chem.MolToSmiles(m)
            m_vec = fragance_propabilities_from_smiles(m_smiles)[0]
            rewards.append(self.cosine_similarity(TARGET_VEC,m_vec))
        return rewards
    
    def cosine_similarity(self,vec1,vec2):
        return np.dot(vec1,vec2)/(norm(vec1)*norm(vec2))

# %%
from gflownet.online_trainer import StandardOnlineTrainer
import socket
from gflownet.envs.mol_building_env import MolBuildingEnvContext

# %%
class ScentTrainer(StandardOnlineTrainer):
    def set_default_hps(self, cfg: Config):
        cfg.hostname = socket.gethostname()
        cfg.algo.method = "TB"
        cfg.algo.max_nodes = 20
        cfg.algo.sampling_tau = 0.9
        cfg.algo.valid_random_action_prob = 0.0
        cfg.num_workers = 8
        cfg.num_training_steps = 100000
        cfg.opt.learning_rate = 1e-6 #1e-4
        cfg.opt.weight_decay = 1e-8
        cfg.opt.momentum = 0.9
        cfg.opt.adam_eps = 1e-8
        cfg.opt.lr_decay = 20000
        cfg.opt.clip_grad_type = "norm"
        cfg.opt.clip_grad_param = 10
        cfg.algo.num_from_policy = 32
        cfg.algo.num_from_dataset = 32
        cfg.algo.train_random_action_prob = 0.001
        cfg.algo.illegal_action_logreward = -75
        cfg.model.num_emb = 128
        cfg.model.num_layers = 4

    def setup_env_context(self):
        self.ctx = MolBuildingEnvContext(
            ['Br', 'C', 'Cl', 'F', 'Fe', 'N', 'Na', 'O', 'S'],
            #["C", "N", "F", "O"],
            #charges=[0],  # disable charge
            chiral_types=[Chem.rdchem.ChiralType.CHI_UNSPECIFIED],  # disable chirality
            expl_H_range=[0,1],
            num_cond_dim=self.task.num_cond_dim,
            max_nodes=self.cfg.algo.max_nodes,
        )

    def setup_data(self):
        self.training_data = OpenPOMDataset(train=True)
        self.test_data = OpenPOMDataset(train=False)

    def setup_task(self):
        self.task = ScentTask(dataset=self.training_data,cfg=self.cfg)

    def setup(self):
        super().setup()
        self.training_data.setup(self.task,self.ctx)
        self.test_data.setup(self.task,self.ctx)

# %%
import pathlib

# %%
def save_run(trial):
    state = {
        "models_state_dict": [trial.model.state_dict()],
        "cfg": trial.cfg,
        "env_ctx": trial.model.env_ctx,
        #"model": trial.model,
    }
    if trial.sampling_model is not trial.model:
        state["sampling_model_state_dict"] = [trial.sampling_model.state_dict()]
    fn = pathlib.Path(trial.cfg.log_dir) / "model_final_save.pt"
    with open(fn, "wb") as fd:
        torch.save(
            state,
            fd,
        )

# %%
config = init_empty(Config())
config.print_every = 1
config.log_dir = "./logs/mcf_smooth_1"


# For CPU
config.device = torch.device('cpu')
config.num_workers = 0

# For reproduction
config.seed = 1 
config.validate_every=100
config.algo.valid_num_from_policy= 32
config.algo.valid_num_from_dataset= 32
config.num_training_steps = 300 #10_000

config.algo.tb.do_parameterize_p_b = False # Dont know how to load the model with this parameter = True
config.num_validation_gen_steps = 1

config.overwrite_existing_exp=True



trial = ScentTrainer(config)
trial.run()
save_run(trial)
# Out:
# c:\Users\paulj\Desktop\Master\venv\lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# c:\Users\paulj\Desktop\Master\venv\lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# c:\Users\paulj\Desktop\Master\venv\lib\site-packages\numpy\lib\function_base.py:2897: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# c:\Users\paulj\Desktop\Master\venv\lib\site-packages\numpy\lib\function_base.py:2898: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# Hyperparameters:
#
# desc: noDesc
# log_dir: ./logs/mcf_smooth_1
# device: cpu
# seed: 1
# validate_every: 100
# checkpoint_every: null
# store_all_checkpoints: false
# print_every: 1
# start_at_step: 0
# num_final_gen_steps: null
# num_validation_gen_steps: 1
# num_training_steps: 300
# num_workers: 0
# hostname: LAPTOP-JIE0TNQT
# pickle_mp_messages: false
# git_hash: e7c59a8
# overwrite_existing_exp: true
# algo:
#   method: TB
#   num_from_policy: 32
#   num_from_dataset: 32
#   valid_num_from_policy: 32
#   valid_num_from_dataset: 32
#   max_len: 128
#   max_nodes: 20
#   max_edges: 128
#   illegal_action_logreward: -75.0
#   train_random_action_prob: 0.001
#   train_det_after: null
#   valid_random_action_prob: 0.0
#   sampling_tau: 0.9
#   tb:
#     bootstrap_own_reward: false
#     epsilon: null
#     reward_loss_multiplier: 1.0
#     variant: TB
#     do_correct_idempotent: false
#     do_parameterize_p_b: false
#     do_predict_n: false
#     do_sample_p_b: false
#     do_length_normalize: false
#     subtb_max_len: 128
#     Z_learning_rate: 0.0001
#     Z_lr_decay: 50000.0
#     cum_subtb: true
#     loss_fn: MSE
#     loss_fn_par: 1.0
#     n_loss: none
#     n_loss_multiplier: 1.0
#     backward_policy: Uniform
#   moql:
#     gamma: 1.0
#     num_omega_samples: 32
#     num_objectives: 2
#     lambda_decay: 10000
#     penalty: -10.0
#   a2c:
#     entropy: 0.01
#     gamma: 1.0
#     penalty: -10.0
#   fm:
#     epsilon: 1.0e-38
#     balanced_loss: false
#     leaf_coef: 10.0
#     correct_idempotent: false
#   sql:
#     alpha: 0.01
#     gamma: 1.0
#     penalty: -10.0
# model:
#   num_layers: 4
#   num_emb: 128
#   dropout: 0.0
#   graph_transformer:
#     num_heads: 2
#     ln_type: pre
#     num_mlp_layers: 0
#     concat_heads: true
#   seq_transformer:
#     num_heads: 2
#     posenc: Rotary
# opt:
#   opt: adam
#   learning_rate: 1.0e-06
#   lr_decay: 20000.0
#   weight_decay: 1.0e-08
#   momentum: 0.9
#   clip_grad_type: norm
#   clip_grad_param: 10.0
#   adam_eps: 1.0e-08
# replay:
#   use: false
#   capacity: null
#   warmup: null
#   hindsight_ratio: 0.0
#   num_from_replay: null
#   num_new_samples: null
# task:
#   qm9:
#     h5_path: ./data/qm9/qm9.h5
#     model_path: ./data/qm9/qm9_model.pt
#   qm9_moo:
#     n_valid: 15
#     n_valid_repeats: 128
#     objectives:
#     - gap
#     - qed
#     - sa
#     online_pareto_front: true
#   seh:
#     reduced_frag: false
#   seh_moo:
#     n_valid: 15
#     n_valid_repeats: 128
#     objectives:
#     - seh
#     - qed
#     - sa
#     - mw
#     log_topk: false
#     online_pareto_front: true
# cond:
#   valid_sample_cond_info: true
#   temperature:
#     sample_dist: uniform
#     dist_params:
#     - 0.5
#     - 32
#     num_thermometer_dim: 32
#   moo:
#     num_objectives: 2
#     num_thermometer_dim: 16
#   weighted_prefs:
#     preference_type: dirichlet
#     preference_param: 1.5
#   focus_region:
#     focus_type: centered
#     use_steer_thermomether: false
#     focus_cosim: 0.98
#     focus_limit_coef: 0.1
#     focus_model_training_limits:
#     - 0.25
#     - 0.75
#     focus_model_state_space_res: 30
#     max_train_it: 20000
#
# 16/04/2025 14:34:02 - INFO - logger - Starting training
# 16/04/2025 14:34:10 - INFO - logger - iteration 1 : offline_loss:5440.63 online_loss:1728.93 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:-0.01 loss:3584.78 n_loss:0.00 tb_loss:3584.78 batch_entropy:48.30 traj_lens:11.88 grad_norm:14291.47 grad_norm_clip:99.15 sampled_reward_avg:0.31 train_time:3.04 time_spent:8.33
# 16/04/2025 14:34:20 - INFO - logger - iteration 2 : offline_loss:348626.69 online_loss:1823.61 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.03 loss:175225.12 n_loss:0.00 tb_loss:175225.12 batch_entropy:99.66 traj_lens:12.16 grad_norm:58079.40 grad_norm_clip:101.00 sampled_reward_avg:0.31 train_time:4.37 time_spent:10.12
# 16/04/2025 14:34:28 - INFO - logger - iteration 3 : offline_loss:7430.74 online_loss:1943.29 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.07 loss:4687.01 n_loss:0.00 tb_loss:4687.01 batch_entropy:52.03 traj_lens:11.58 grad_norm:18418.57 grad_norm_clip:99.52 sampled_reward_avg:0.27 train_time:3.17 time_spent:7.25
# 16/04/2025 14:34:35 - INFO - logger - iteration 4 : offline_loss:2170.16 online_loss:2246.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.11 loss:2208.34 n_loss:0.00 tb_loss:2208.34 batch_entropy:41.32 traj_lens:11.14 grad_norm:8831.85 grad_norm_clip:97.86 sampled_reward_avg:0.27 train_time:2.51 time_spent:6.97
# 16/04/2025 14:34:43 - INFO - logger - iteration 5 : offline_loss:2392.38 online_loss:1595.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.15 loss:1993.95 n_loss:0.00 tb_loss:1993.95 batch_entropy:41.36 traj_lens:11.00 grad_norm:9571.83 grad_norm_clip:98.17 sampled_reward_avg:0.32 train_time:2.79 time_spent:8.48
# 16/04/2025 14:34:53 - INFO - logger - iteration 6 : offline_loss:54080.08 online_loss:1611.19 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.19 loss:27845.63 n_loss:0.00 tb_loss:27845.63 batch_entropy:63.85 traj_lens:12.38 grad_norm:23804.78 grad_norm_clip:100.67 sampled_reward_avg:0.35 train_time:3.51 time_spent:9.57
# 16/04/2025 14:35:03 - INFO - logger - iteration 7 : offline_loss:17119.35 online_loss:1400.40 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.23 loss:9259.88 n_loss:0.00 tb_loss:9259.88 batch_entropy:65.67 traj_lens:12.86 grad_norm:26461.93 grad_norm_clip:100.56 sampled_reward_avg:0.35 train_time:3.70 time_spent:10.37
# 16/04/2025 14:35:13 - INFO - logger - iteration 8 : offline_loss:54049.32 online_loss:1569.80 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.27 loss:27809.56 n_loss:0.00 tb_loss:27809.56 batch_entropy:64.99 traj_lens:12.53 grad_norm:22871.90 grad_norm_clip:100.55 sampled_reward_avg:0.36 train_time:3.93 time_spent:10.53
# 16/04/2025 14:35:22 - INFO - logger - iteration 9 : offline_loss:9245.37 online_loss:1845.63 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.31 loss:5545.50 n_loss:0.00 tb_loss:5545.50 batch_entropy:49.29 traj_lens:11.72 grad_norm:14591.89 grad_norm_clip:99.64 sampled_reward_avg:0.31 train_time:3.19 time_spent:8.28
# 16/04/2025 14:35:31 - INFO - logger - iteration 10 : offline_loss:4426.09 online_loss:1913.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.35 loss:3169.60 n_loss:0.00 tb_loss:3169.60 batch_entropy:51.13 traj_lens:12.95 grad_norm:14508.76 grad_norm_clip:99.12 sampled_reward_avg:0.28 train_time:3.46 time_spent:8.91
# 16/04/2025 14:35:39 - INFO - logger - iteration 11 : offline_loss:3054.33 online_loss:1272.05 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.39 loss:2163.19 n_loss:0.00 tb_loss:2163.19 batch_entropy:47.89 traj_lens:12.58 grad_norm:11671.49 grad_norm_clip:98.76 sampled_reward_avg:0.34 train_time:3.35 time_spent:8.75
# 16/04/2025 14:35:48 - INFO - logger - iteration 12 : offline_loss:7894.75 online_loss:973.33 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.43 loss:4434.04 n_loss:0.00 tb_loss:4434.04 batch_entropy:51.16 traj_lens:12.23 grad_norm:14976.11 grad_norm_clip:99.90 sampled_reward_avg:0.40 train_time:3.22 time_spent:8.99
# 16/04/2025 14:35:58 - INFO - logger - iteration 13 : offline_loss:9501.30 online_loss:1388.87 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.48 loss:5445.09 n_loss:0.00 tb_loss:5445.09 batch_entropy:57.77 traj_lens:13.14 grad_norm:18358.04 grad_norm_clip:100.44 sampled_reward_avg:0.38 train_time:3.90 time_spent:9.69
# 16/04/2025 14:36:06 - INFO - logger - iteration 14 : offline_loss:5988.56 online_loss:1648.31 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.52 loss:3818.43 n_loss:0.00 tb_loss:3818.43 batch_entropy:49.07 traj_lens:11.75 grad_norm:14065.75 grad_norm_clip:99.19 sampled_reward_avg:0.32 train_time:3.11 time_spent:8.09
# 16/04/2025 14:36:15 - INFO - logger - iteration 15 : offline_loss:2296.77 online_loss:1744.57 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.56 loss:2020.67 n_loss:0.00 tb_loss:2020.67 batch_entropy:44.04 traj_lens:11.88 grad_norm:9192.04 grad_norm_clip:98.10 sampled_reward_avg:0.33 train_time:3.05 time_spent:8.57
# 16/04/2025 14:36:24 - INFO - logger - iteration 16 : offline_loss:2598.83 online_loss:1248.77 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.60 loss:1923.80 n_loss:0.00 tb_loss:1923.80 batch_entropy:42.85 traj_lens:11.48 grad_norm:9795.91 grad_norm_clip:98.44 sampled_reward_avg:0.40 train_time:3.23 time_spent:9.60
# 16/04/2025 14:36:32 - INFO - logger - iteration 17 : offline_loss:3279.42 online_loss:1904.03 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.64 loss:2591.72 n_loss:0.00 tb_loss:2591.72 batch_entropy:42.13 traj_lens:10.94 grad_norm:10355.76 grad_norm_clip:98.34 sampled_reward_avg:0.26 train_time:2.75 time_spent:7.44
# 16/04/2025 14:36:38 - INFO - logger - iteration 18 : offline_loss:2045.22 online_loss:1803.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.68 loss:1924.17 n_loss:0.00 tb_loss:1924.17 batch_entropy:37.42 traj_lens:10.19 grad_norm:8606.75 grad_norm_clip:97.88 sampled_reward_avg:0.32 train_time:2.49 time_spent:6.68
# 16/04/2025 14:36:47 - INFO - logger - iteration 19 : offline_loss:7920.07 online_loss:1897.47 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.72 loss:4908.77 n_loss:0.00 tb_loss:4908.77 batch_entropy:49.30 traj_lens:11.91 grad_norm:15322.70 grad_norm_clip:99.59 sampled_reward_avg:0.29 train_time:3.22 time_spent:8.52
# 16/04/2025 14:36:55 - INFO - logger - iteration 20 : offline_loss:5640.84 online_loss:1712.76 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.76 loss:3676.80 n_loss:0.00 tb_loss:3676.80 batch_entropy:46.62 traj_lens:11.75 grad_norm:11693.73 grad_norm_clip:98.80 sampled_reward_avg:0.31 train_time:2.95 time_spent:7.85
# 16/04/2025 14:37:04 - INFO - logger - iteration 21 : offline_loss:2544.38 online_loss:1695.21 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.80 loss:2119.79 n_loss:0.00 tb_loss:2119.79 batch_entropy:44.90 traj_lens:12.02 grad_norm:10432.00 grad_norm_clip:98.49 sampled_reward_avg:0.31 train_time:3.11 time_spent:8.68
# 16/04/2025 14:37:11 - INFO - logger - iteration 22 : offline_loss:2100.07 online_loss:1331.66 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.83 loss:1715.86 n_loss:0.00 tb_loss:1715.86 batch_entropy:38.53 traj_lens:10.56 grad_norm:8456.02 grad_norm_clip:98.11 sampled_reward_avg:0.35 train_time:2.36 time_spent:7.23
# 16/04/2025 14:37:17 - INFO - logger - iteration 23 : offline_loss:1504.59 online_loss:1809.54 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.87 loss:1657.07 n_loss:0.00 tb_loss:1657.07 batch_entropy:35.18 traj_lens:10.00 grad_norm:6124.79 grad_norm_clip:97.04 sampled_reward_avg:0.30 train_time:2.09 time_spent:6.37
# 16/04/2025 14:37:23 - INFO - logger - iteration 24 : offline_loss:1907.97 online_loss:2281.36 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.91 loss:2094.67 n_loss:0.00 tb_loss:2094.67 batch_entropy:38.63 traj_lens:10.66 grad_norm:7993.97 grad_norm_clip:97.31 sampled_reward_avg:0.25 train_time:2.41 time_spent:6.04
# 16/04/2025 14:37:31 - INFO - logger - iteration 25 : offline_loss:1924.72 online_loss:1261.23 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:0.96 loss:1592.98 n_loss:0.00 tb_loss:1592.98 batch_entropy:41.28 traj_lens:11.67 grad_norm:7832.43 grad_norm_clip:98.06 sampled_reward_avg:0.38 train_time:2.72 time_spent:8.18
# 16/04/2025 14:37:38 - INFO - logger - iteration 26 : offline_loss:19967.84 online_loss:1539.47 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.00 loss:10753.65 n_loss:0.00 tb_loss:10753.65 batch_entropy:50.25 traj_lens:10.84 grad_norm:16409.91 grad_norm_clip:99.68 sampled_reward_avg:0.33 train_time:2.59 time_spent:6.42
# 16/04/2025 14:37:44 - INFO - logger - iteration 27 : offline_loss:1895.54 online_loss:1456.70 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.04 loss:1676.12 n_loss:0.00 tb_loss:1676.12 batch_entropy:35.02 traj_lens:9.88 grad_norm:7665.61 grad_norm_clip:97.84 sampled_reward_avg:0.37 train_time:2.15 time_spent:5.80
# 16/04/2025 14:37:51 - INFO - logger - iteration 28 : offline_loss:6073.52 online_loss:1661.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.08 loss:3867.53 n_loss:0.00 tb_loss:3867.53 batch_entropy:45.83 traj_lens:11.36 grad_norm:11811.59 grad_norm_clip:98.89 sampled_reward_avg:0.32 train_time:2.77 time_spent:7.79
# 16/04/2025 14:38:01 - INFO - logger - iteration 29 : offline_loss:5578.17 online_loss:1731.10 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.12 loss:3654.63 n_loss:0.00 tb_loss:3654.63 batch_entropy:47.57 traj_lens:12.08 grad_norm:11679.27 grad_norm_clip:99.01 sampled_reward_avg:0.31 train_time:3.17 time_spent:9.35
# 16/04/2025 14:38:08 - INFO - logger - iteration 30 : offline_loss:3532.05 online_loss:1541.51 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.16 loss:2536.78 n_loss:0.00 tb_loss:2536.78 batch_entropy:43.86 traj_lens:11.30 grad_norm:11102.39 grad_norm_clip:98.62 sampled_reward_avg:0.34 train_time:2.87 time_spent:7.65
# 16/04/2025 14:38:17 - INFO - logger - iteration 31 : offline_loss:8524.29 online_loss:1087.24 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.21 loss:4805.77 n_loss:0.00 tb_loss:4805.77 batch_entropy:45.84 traj_lens:11.08 grad_norm:12627.42 grad_norm_clip:99.58 sampled_reward_avg:0.41 train_time:2.93 time_spent:8.28
# 16/04/2025 14:38:23 - INFO - logger - iteration 32 : offline_loss:1900.09 online_loss:1316.56 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.25 loss:1608.33 n_loss:0.00 tb_loss:1608.33 batch_entropy:37.62 traj_lens:10.58 grad_norm:7854.59 grad_norm_clip:97.98 sampled_reward_avg:0.38 train_time:2.38 time_spent:6.76
# 16/04/2025 14:38:32 - INFO - logger - iteration 33 : offline_loss:1986.23 online_loss:1549.15 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.29 loss:1767.69 n_loss:0.00 tb_loss:1767.69 batch_entropy:43.08 traj_lens:11.94 grad_norm:8523.12 grad_norm_clip:98.26 sampled_reward_avg:0.35 train_time:3.40 time_spent:9.07
# 16/04/2025 14:38:42 - INFO - logger - iteration 34 : offline_loss:1825.66 online_loss:1985.03 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.34 loss:1905.35 n_loss:0.00 tb_loss:1905.35 batch_entropy:41.32 traj_lens:11.47 grad_norm:8154.93 grad_norm_clip:97.93 sampled_reward_avg:0.33 train_time:3.36 time_spent:9.65
# 16/04/2025 14:38:52 - INFO - logger - iteration 35 : offline_loss:1985.21 online_loss:1861.34 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.38 loss:1923.27 n_loss:0.00 tb_loss:1923.27 batch_entropy:42.40 traj_lens:11.75 grad_norm:8068.33 grad_norm_clip:97.55 sampled_reward_avg:0.33 train_time:3.39 time_spent:9.97
# 16/04/2025 14:39:04 - INFO - logger - iteration 36 : offline_loss:2215.39 online_loss:1663.26 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.42 loss:1939.33 n_loss:0.00 tb_loss:1939.33 batch_entropy:49.42 traj_lens:13.48 grad_norm:9553.10 grad_norm_clip:98.77 sampled_reward_avg:0.38 train_time:4.17 time_spent:11.59
# 16/04/2025 14:39:11 - INFO - logger - iteration 37 : offline_loss:6266.73 online_loss:1805.59 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.47 loss:4036.16 n_loss:0.00 tb_loss:4036.16 batch_entropy:47.20 traj_lens:11.62 grad_norm:13740.26 grad_norm_clip:99.48 sampled_reward_avg:0.31 train_time:3.08 time_spent:7.61
# 16/04/2025 14:39:20 - INFO - logger - iteration 38 : offline_loss:52387.54 online_loss:1611.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.51 loss:26999.55 n_loss:0.00 tb_loss:26999.55 batch_entropy:58.31 traj_lens:11.09 grad_norm:21672.87 grad_norm_clip:100.35 sampled_reward_avg:0.30 train_time:3.01 time_spent:8.32
# 16/04/2025 14:39:29 - INFO - logger - iteration 39 : offline_loss:59822.09 online_loss:1750.16 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.55 loss:30786.12 n_loss:0.00 tb_loss:30786.12 batch_entropy:67.21 traj_lens:12.75 grad_norm:24280.13 grad_norm_clip:100.28 sampled_reward_avg:0.35 train_time:3.60 time_spent:9.66
# 16/04/2025 14:39:37 - INFO - logger - iteration 40 : offline_loss:1655.81 online_loss:1103.15 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.60 loss:1379.48 n_loss:0.00 tb_loss:1379.48 batch_entropy:40.38 traj_lens:11.39 grad_norm:7103.10 grad_norm_clip:97.58 sampled_reward_avg:0.41 train_time:2.76 time_spent:8.01
# 16/04/2025 14:39:47 - INFO - logger - iteration 41 : offline_loss:5717.76 online_loss:929.19 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.64 loss:3323.47 n_loss:0.00 tb_loss:3323.47 batch_entropy:46.62 traj_lens:11.77 grad_norm:11868.29 grad_norm_clip:99.35 sampled_reward_avg:0.44 train_time:3.05 time_spent:9.27
# 16/04/2025 14:39:54 - INFO - logger - iteration 42 : offline_loss:2163.46 online_loss:2014.40 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.69 loss:2088.93 n_loss:0.00 tb_loss:2088.93 batch_entropy:40.62 traj_lens:11.25 grad_norm:9100.53 grad_norm_clip:98.06 sampled_reward_avg:0.30 train_time:2.94 time_spent:7.63
# 16/04/2025 14:40:01 - INFO - logger - iteration 43 : offline_loss:49446.30 online_loss:1774.12 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.74 loss:25610.21 n_loss:0.00 tb_loss:25610.21 batch_entropy:66.82 traj_lens:11.22 grad_norm:28241.94 grad_norm_clip:100.79 sampled_reward_avg:0.31 train_time:3.06 time_spent:7.24
# 16/04/2025 14:40:09 - INFO - logger - iteration 44 : offline_loss:3218.54 online_loss:1375.23 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.78 loss:2296.89 n_loss:0.00 tb_loss:2296.89 batch_entropy:45.46 traj_lens:12.28 grad_norm:10233.41 grad_norm_clip:99.08 sampled_reward_avg:0.37 train_time:3.28 time_spent:7.88
# 16/04/2025 14:40:18 - INFO - logger - iteration 45 : offline_loss:19851.49 online_loss:1381.35 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.83 loss:10616.42 n_loss:0.00 tb_loss:10616.42 batch_entropy:53.69 traj_lens:11.80 grad_norm:21358.39 grad_norm_clip:100.53 sampled_reward_avg:0.36 train_time:3.07 time_spent:8.24
# 16/04/2025 14:40:25 - INFO - logger - iteration 46 : offline_loss:2117.51 online_loss:1780.61 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.88 loss:1949.06 n_loss:0.00 tb_loss:1949.06 batch_entropy:41.13 traj_lens:11.34 grad_norm:8037.63 grad_norm_clip:98.00 sampled_reward_avg:0.32 train_time:2.77 time_spent:7.74
# 16/04/2025 14:40:35 - INFO - logger - iteration 47 : offline_loss:1871.65 online_loss:1532.01 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.93 loss:1701.83 n_loss:0.00 tb_loss:1701.83 batch_entropy:43.50 traj_lens:12.16 grad_norm:8250.06 grad_norm_clip:98.45 sampled_reward_avg:0.35 train_time:3.28 time_spent:9.53
# 16/04/2025 14:40:43 - INFO - logger - iteration 48 : offline_loss:1921.12 online_loss:1839.34 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:1.98 loss:1880.23 n_loss:0.00 tb_loss:1880.23 batch_entropy:44.02 traj_lens:12.30 grad_norm:8640.86 grad_norm_clip:98.34 sampled_reward_avg:0.32 train_time:3.10 time_spent:8.27
# 16/04/2025 14:40:52 - INFO - logger - iteration 49 : offline_loss:1857.76 online_loss:2002.10 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.03 loss:1929.93 n_loss:0.00 tb_loss:1929.93 batch_entropy:41.95 traj_lens:11.88 grad_norm:8637.80 grad_norm_clip:98.06 sampled_reward_avg:0.31 train_time:3.39 time_spent:9.19
# 16/04/2025 14:41:00 - INFO - logger - iteration 50 : offline_loss:12939.02 online_loss:2188.78 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.08 loss:7563.90 n_loss:0.00 tb_loss:7563.90 batch_entropy:53.85 traj_lens:11.94 grad_norm:17577.38 grad_norm_clip:100.17 sampled_reward_avg:0.28 train_time:3.15 time_spent:7.64
# 16/04/2025 14:41:09 - INFO - logger - iteration 51 : offline_loss:1645.08 online_loss:553.13 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.13 loss:1099.11 n_loss:0.00 tb_loss:1099.11 batch_entropy:42.81 traj_lens:12.36 grad_norm:7188.31 grad_norm_clip:98.50 sampled_reward_avg:0.47 train_time:3.12 time_spent:9.17
# 16/04/2025 14:41:17 - INFO - logger - iteration 52 : offline_loss:1706.88 online_loss:1550.40 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.18 loss:1628.64 n_loss:0.00 tb_loss:1628.64 batch_entropy:40.35 traj_lens:11.38 grad_norm:7182.20 grad_norm_clip:97.57 sampled_reward_avg:0.34 train_time:2.69 time_spent:7.58
# 16/04/2025 14:41:25 - INFO - logger - iteration 53 : offline_loss:22573.28 online_loss:1840.78 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.23 loss:12207.03 n_loss:0.00 tb_loss:12207.03 batch_entropy:57.34 traj_lens:11.88 grad_norm:21026.50 grad_norm_clip:100.54 sampled_reward_avg:0.31 train_time:3.12 time_spent:8.30
# 16/04/2025 14:41:34 - INFO - logger - iteration 54 : offline_loss:2363.48 online_loss:1498.72 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.28 loss:1931.10 n_loss:0.00 tb_loss:1931.10 batch_entropy:46.48 traj_lens:12.89 grad_norm:8964.28 grad_norm_clip:98.85 sampled_reward_avg:0.34 train_time:3.38 time_spent:9.11
# 16/04/2025 14:41:41 - INFO - logger - iteration 55 : offline_loss:1638.09 online_loss:2114.83 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.34 loss:1876.46 n_loss:0.00 tb_loss:1876.46 batch_entropy:39.74 traj_lens:11.06 grad_norm:6952.29 grad_norm_clip:96.76 sampled_reward_avg:0.29 train_time:2.73 time_spent:7.40
# 16/04/2025 14:41:50 - INFO - logger - iteration 56 : offline_loss:2198.18 online_loss:1793.08 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.39 loss:1995.63 n_loss:0.00 tb_loss:1995.63 batch_entropy:44.65 traj_lens:12.27 grad_norm:8300.55 grad_norm_clip:98.38 sampled_reward_avg:0.27 train_time:3.42 time_spent:8.54
# 16/04/2025 14:41:58 - INFO - logger - iteration 57 : offline_loss:2182.68 online_loss:1499.65 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.44 loss:1841.16 n_loss:0.00 tb_loss:1841.16 batch_entropy:40.87 traj_lens:11.28 grad_norm:8652.62 grad_norm_clip:98.64 sampled_reward_avg:0.34 train_time:2.85 time_spent:7.75
# 16/04/2025 14:42:06 - INFO - logger - iteration 58 : offline_loss:5535.64 online_loss:846.51 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.50 loss:3191.07 n_loss:0.00 tb_loss:3191.07 batch_entropy:48.64 traj_lens:12.36 grad_norm:13015.00 grad_norm_clip:99.53 sampled_reward_avg:0.43 train_time:3.35 time_spent:8.58
# 16/04/2025 14:42:15 - INFO - logger - iteration 59 : offline_loss:1461.86 online_loss:1608.62 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.55 loss:1535.24 n_loss:0.00 tb_loss:1535.24 batch_entropy:39.91 traj_lens:11.62 grad_norm:6291.66 grad_norm_clip:97.63 sampled_reward_avg:0.35 train_time:2.84 time_spent:9.06
# 16/04/2025 14:42:22 - INFO - logger - iteration 60 : offline_loss:1601.57 online_loss:2535.82 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.61 loss:2068.69 n_loss:0.00 tb_loss:2068.69 batch_entropy:38.00 traj_lens:10.88 grad_norm:7283.19 grad_norm_clip:97.03 sampled_reward_avg:0.26 train_time:2.55 time_spent:6.78
# 16/04/2025 14:42:29 - INFO - logger - iteration 61 : offline_loss:2328.25 online_loss:1484.10 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.66 loss:1906.18 n_loss:0.00 tb_loss:1906.18 batch_entropy:40.65 traj_lens:11.11 grad_norm:9245.48 grad_norm_clip:98.84 sampled_reward_avg:0.36 train_time:2.72 time_spent:6.72
# 16/04/2025 14:42:35 - INFO - logger - iteration 62 : offline_loss:1723.13 online_loss:1260.82 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.72 loss:1491.97 n_loss:0.00 tb_loss:1491.97 batch_entropy:37.94 traj_lens:10.94 grad_norm:7760.68 grad_norm_clip:98.45 sampled_reward_avg:0.39 train_time:2.48 time_spent:6.56
# 16/04/2025 14:42:45 - INFO - logger - iteration 63 : offline_loss:4219.73 online_loss:1223.32 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.77 loss:2721.53 n_loss:0.00 tb_loss:2721.53 batch_entropy:48.21 traj_lens:12.75 grad_norm:10889.91 grad_norm_clip:99.21 sampled_reward_avg:0.35 train_time:3.50 time_spent:9.24
# 16/04/2025 14:42:54 - INFO - logger - iteration 64 : offline_loss:5921.22 online_loss:1860.37 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.83 loss:3890.80 n_loss:0.00 tb_loss:3890.80 batch_entropy:50.49 traj_lens:12.67 grad_norm:12499.24 grad_norm_clip:99.50 sampled_reward_avg:0.32 train_time:3.40 time_spent:9.07
# 16/04/2025 14:43:04 - INFO - logger - iteration 65 : offline_loss:7744.93 online_loss:1966.95 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.89 loss:4855.94 n_loss:0.00 tb_loss:4855.94 batch_entropy:54.07 traj_lens:13.08 grad_norm:14581.59 grad_norm_clip:99.71 sampled_reward_avg:0.28 train_time:3.71 time_spent:10.30
# 16/04/2025 14:43:13 - INFO - logger - iteration 66 : offline_loss:5786.50 online_loss:1582.22 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:2.94 loss:3684.36 n_loss:0.00 tb_loss:3684.36 batch_entropy:49.68 traj_lens:12.66 grad_norm:12932.82 grad_norm_clip:99.68 sampled_reward_avg:0.35 train_time:3.41 time_spent:8.78
# 16/04/2025 14:43:21 - INFO - logger - iteration 67 : offline_loss:1562.90 online_loss:1824.85 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.00 loss:1693.88 n_loss:0.00 tb_loss:1693.88 batch_entropy:38.91 traj_lens:11.27 grad_norm:6671.00 grad_norm_clip:97.01 sampled_reward_avg:0.30 train_time:2.96 time_spent:7.98
# 16/04/2025 14:43:29 - INFO - logger - iteration 68 : offline_loss:2740.21 online_loss:1742.55 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.06 loss:2241.38 n_loss:0.00 tb_loss:2241.38 batch_entropy:43.11 traj_lens:11.56 grad_norm:8689.97 grad_norm_clip:98.74 sampled_reward_avg:0.34 train_time:2.94 time_spent:7.84
# 16/04/2025 14:43:41 - INFO - logger - iteration 69 : offline_loss:1585.94 online_loss:1359.36 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.11 loss:1472.65 n_loss:0.00 tb_loss:1472.65 batch_entropy:48.87 traj_lens:13.66 grad_norm:7077.14 grad_norm_clip:97.41 sampled_reward_avg:0.39 train_time:4.81 time_spent:12.53
# 16/04/2025 14:43:49 - INFO - logger - iteration 70 : offline_loss:53889.99 online_loss:1481.75 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.17 loss:27685.87 n_loss:0.00 tb_loss:27685.87 batch_entropy:60.67 traj_lens:11.48 grad_norm:21955.63 grad_norm_clip:100.23 sampled_reward_avg:0.36 train_time:3.54 time_spent:7.97
# 16/04/2025 14:44:01 - INFO - logger - iteration 71 : offline_loss:6960.22 online_loss:1434.29 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.23 loss:4197.25 n_loss:0.00 tb_loss:4197.25 batch_entropy:54.70 traj_lens:14.05 grad_norm:11704.92 grad_norm_clip:99.36 sampled_reward_avg:0.34 train_time:4.26 time_spent:11.60
# 16/04/2025 14:44:09 - INFO - logger - iteration 72 : offline_loss:1530.99 online_loss:1557.13 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.29 loss:1544.06 n_loss:0.00 tb_loss:1544.06 batch_entropy:39.64 traj_lens:11.42 grad_norm:6847.45 grad_norm_clip:97.88 sampled_reward_avg:0.36 train_time:3.17 time_spent:8.69
# 16/04/2025 14:44:20 - INFO - logger - iteration 73 : offline_loss:2246.47 online_loss:1552.13 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.35 loss:1899.30 n_loss:0.00 tb_loss:1899.30 batch_entropy:48.97 traj_lens:13.50 grad_norm:8694.29 grad_norm_clip:98.48 sampled_reward_avg:0.33 train_time:4.10 time_spent:10.35
# 16/04/2025 14:44:28 - INFO - logger - iteration 74 : offline_loss:7424.59 online_loss:2445.04 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.41 loss:4934.82 n_loss:0.00 tb_loss:4934.82 batch_entropy:52.80 traj_lens:12.86 grad_norm:13094.81 grad_norm_clip:99.66 sampled_reward_avg:0.22 train_time:3.62 time_spent:8.46
# 16/04/2025 14:44:36 - INFO - logger - iteration 75 : offline_loss:132448.77 online_loss:2387.46 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.47 loss:67418.12 n_loss:0.00 tb_loss:67418.12 batch_entropy:70.91 traj_lens:11.53 grad_norm:41678.29 grad_norm_clip:100.81 sampled_reward_avg:0.23 train_time:3.53 time_spent:8.01
# 16/04/2025 14:44:46 - INFO - logger - iteration 76 : offline_loss:1855.98 online_loss:1733.26 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.53 loss:1794.62 n_loss:0.00 tb_loss:1794.62 batch_entropy:45.24 traj_lens:12.94 grad_norm:7238.29 grad_norm_clip:97.72 sampled_reward_avg:0.27 train_time:3.59 time_spent:9.62
# 16/04/2025 14:44:56 - INFO - logger - iteration 77 : offline_loss:3780.08 online_loss:1873.36 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.60 loss:2826.72 n_loss:0.00 tb_loss:2826.72 batch_entropy:50.55 traj_lens:13.56 grad_norm:10088.08 grad_norm_clip:99.14 sampled_reward_avg:0.28 train_time:4.06 time_spent:10.19
# 16/04/2025 14:45:03 - INFO - logger - iteration 78 : offline_loss:1210.56 online_loss:2007.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.66 loss:1608.78 n_loss:0.00 tb_loss:1608.78 batch_entropy:32.42 traj_lens:9.61 grad_norm:5447.67 grad_norm_clip:96.11 sampled_reward_avg:0.33 train_time:2.27 time_spent:6.81
# 16/04/2025 14:45:13 - INFO - logger - iteration 79 : offline_loss:3018.43 online_loss:1177.97 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.72 loss:2098.20 n_loss:0.00 tb_loss:2098.20 batch_entropy:50.78 traj_lens:13.78 grad_norm:9252.86 grad_norm_clip:98.95 sampled_reward_avg:0.36 train_time:4.04 time_spent:10.57
# 16/04/2025 14:45:25 - INFO - logger - iteration 80 : offline_loss:85291.79 online_loss:1275.82 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.78 loss:43283.80 n_loss:0.00 tb_loss:43283.80 batch_entropy:84.29 traj_lens:15.03 grad_norm:30609.80 grad_norm_clip:100.96 sampled_reward_avg:0.36 train_time:4.78 time_spent:11.46
# 16/04/2025 14:45:32 - INFO - logger - iteration 81 : offline_loss:1557.95 online_loss:1756.47 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.85 loss:1657.21 n_loss:0.00 tb_loss:1657.21 batch_entropy:39.51 traj_lens:11.42 grad_norm:6720.90 grad_norm_clip:97.18 sampled_reward_avg:0.30 train_time:2.81 time_spent:6.93
# 16/04/2025 14:45:44 - INFO - logger - iteration 82 : offline_loss:11848.98 online_loss:1189.35 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.91 loss:6519.17 n_loss:0.00 tb_loss:6519.17 batch_entropy:59.83 traj_lens:14.56 grad_norm:13433.47 grad_norm_clip:99.40 sampled_reward_avg:0.38 train_time:4.22 time_spent:11.77
# 16/04/2025 14:45:53 - INFO - logger - iteration 83 : offline_loss:4931.72 online_loss:1700.03 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:3.97 loss:3315.87 n_loss:0.00 tb_loss:3315.87 batch_entropy:48.04 traj_lens:12.38 grad_norm:10250.78 grad_norm_clip:99.04 sampled_reward_avg:0.32 train_time:3.49 time_spent:9.13
# 16/04/2025 14:46:03 - INFO - logger - iteration 84 : offline_loss:86129.49 online_loss:2029.15 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.04 loss:44079.32 n_loss:0.00 tb_loss:44079.32 batch_entropy:72.11 traj_lens:12.36 grad_norm:30027.55 grad_norm_clip:100.56 sampled_reward_avg:0.33 train_time:3.82 time_spent:10.03
# 16/04/2025 14:46:10 - INFO - logger - iteration 85 : offline_loss:4418.75 online_loss:2615.14 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.10 loss:3516.94 n_loss:0.00 tb_loss:3516.94 batch_entropy:41.92 traj_lens:11.08 grad_norm:8759.46 grad_norm_clip:97.83 sampled_reward_avg:0.24 train_time:2.72 time_spent:6.99
# 16/04/2025 14:46:19 - INFO - logger - iteration 86 : offline_loss:2457.21 online_loss:1259.10 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.17 loss:1858.16 n_loss:0.00 tb_loss:1858.16 batch_entropy:45.34 traj_lens:12.47 grad_norm:8265.29 grad_norm_clip:98.62 sampled_reward_avg:0.36 train_time:3.39 time_spent:8.98
# 16/04/2025 14:46:31 - INFO - logger - iteration 87 : offline_loss:18697.10 online_loss:1328.04 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.23 loss:10012.57 n_loss:0.00 tb_loss:10012.57 batch_entropy:61.27 traj_lens:14.39 grad_norm:13330.94 grad_norm_clip:99.50 sampled_reward_avg:0.37 train_time:4.41 time_spent:11.78
# 16/04/2025 14:46:42 - INFO - logger - iteration 88 : offline_loss:390540.78 online_loss:1256.17 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.30 loss:195898.48 n_loss:0.00 tb_loss:195898.48 batch_entropy:112.05 traj_lens:12.64 grad_norm:58939.09 grad_norm_clip:101.00 sampled_reward_avg:0.40 train_time:4.89 time_spent:11.31
# 16/04/2025 14:46:50 - INFO - logger - iteration 89 : offline_loss:1327.91 online_loss:1922.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.37 loss:1625.22 n_loss:0.00 tb_loss:1625.22 batch_entropy:43.04 traj_lens:12.50 grad_norm:6187.80 grad_norm_clip:97.53 sampled_reward_avg:0.32 train_time:3.28 time_spent:8.44
# 16/04/2025 14:47:00 - INFO - logger - iteration 90 : offline_loss:16058.37 online_loss:1356.33 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.43 loss:8707.35 n_loss:0.00 tb_loss:8707.35 batch_entropy:53.95 traj_lens:12.94 grad_norm:13113.52 grad_norm_clip:99.84 sampled_reward_avg:0.35 train_time:3.79 time_spent:9.76
# 16/04/2025 14:47:11 - INFO - logger - iteration 91 : offline_loss:2630.83 online_loss:1572.53 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.50 loss:2101.68 n_loss:0.00 tb_loss:2101.68 batch_entropy:49.86 traj_lens:13.81 grad_norm:8646.00 grad_norm_clip:98.46 sampled_reward_avg:0.36 train_time:4.18 time_spent:10.74
# 16/04/2025 14:47:20 - INFO - logger - iteration 92 : offline_loss:1230.25 online_loss:1903.39 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.57 loss:1566.82 n_loss:0.00 tb_loss:1566.82 batch_entropy:41.22 traj_lens:12.12 grad_norm:5394.93 grad_norm_clip:96.48 sampled_reward_avg:0.27 train_time:3.21 time_spent:9.19
# 16/04/2025 14:47:28 - INFO - logger - iteration 93 : offline_loss:8343.17 online_loss:1644.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.63 loss:4993.59 n_loss:0.00 tb_loss:4993.59 batch_entropy:44.06 traj_lens:10.94 grad_norm:10372.03 grad_norm_clip:99.01 sampled_reward_avg:0.33 train_time:2.91 time_spent:8.26
# 16/04/2025 14:47:37 - INFO - logger - iteration 94 : offline_loss:1113.54 online_loss:2009.49 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.70 loss:1561.52 n_loss:0.00 tb_loss:1561.52 batch_entropy:42.26 traj_lens:12.53 grad_norm:5310.25 grad_norm_clip:96.68 sampled_reward_avg:0.32 train_time:3.31 time_spent:8.79
# 16/04/2025 14:47:47 - INFO - logger - iteration 95 : offline_loss:2664.41 online_loss:1212.04 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.77 loss:1938.22 n_loss:0.00 tb_loss:1938.22 batch_entropy:48.02 traj_lens:13.25 grad_norm:8392.33 grad_norm_clip:98.74 sampled_reward_avg:0.40 train_time:3.85 time_spent:10.14
# 16/04/2025 14:47:59 - INFO - logger - iteration 96 : offline_loss:32373.08 online_loss:2074.05 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.84 loss:17223.56 n_loss:0.00 tb_loss:17223.56 batch_entropy:61.47 traj_lens:13.44 grad_norm:24498.87 grad_norm_clip:100.53 sampled_reward_avg:0.26 train_time:5.21 time_spent:11.49
# 16/04/2025 14:48:09 - INFO - logger - iteration 97 : offline_loss:939.74 online_loss:2290.46 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.91 loss:1615.10 n_loss:0.00 tb_loss:1615.10 batch_entropy:37.80 traj_lens:11.14 grad_norm:4184.55 grad_norm_clip:94.30 sampled_reward_avg:0.27 train_time:3.73 time_spent:10.21
# 16/04/2025 14:48:20 - INFO - logger - iteration 98 : offline_loss:3056.86 online_loss:1417.16 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:4.97 loss:2237.01 n_loss:0.00 tb_loss:2237.01 batch_entropy:46.50 traj_lens:12.53 grad_norm:9521.25 grad_norm_clip:99.00 sampled_reward_avg:0.36 train_time:3.98 time_spent:10.80
# 16/04/2025 14:48:31 - INFO - logger - iteration 99 : offline_loss:932.19 online_loss:1476.75 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.04 loss:1204.47 n_loss:0.00 tb_loss:1204.47 batch_entropy:39.34 traj_lens:11.72 grad_norm:4513.80 grad_norm_clip:96.62 sampled_reward_avg:0.35 train_time:4.74 time_spent:11.61
# 16/04/2025 14:48:46 - INFO - logger - iteration 100 : offline_loss:1462.03 online_loss:1218.76 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.11 loss:1340.40 n_loss:0.00 tb_loss:1340.40 batch_entropy:42.74 traj_lens:12.75 grad_norm:7077.66 grad_norm_clip:98.47 sampled_reward_avg:0.39 train_time:5.89 time_spent:14.43
# 16/04/2025 14:48:55 - INFO - logger - validation - iteration 100 : offline_loss:2369.21 online_loss:2387.32 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:2378.27 n_loss:0.00 tb_loss:2378.27 batch_entropy:43.36 traj_lens:12.28 sampled_reward_avg:0.24 eval_time:2.55
# c:\Users\paulj\Desktop\Master\venv\lib\site-packages\gflownet\data\data_source.py:70: UserWarning: Some iterators are done, but not all. You may be mixing incompatible iterators.
#   warnings.warn("Some iterators are done, but not all. You may be mixing incompatible iterators.")
# 16/04/2025 14:48:59 - INFO - logger - validation - iteration 100 : offline_loss:14415.11 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:14415.11 n_loss:0.00 tb_loss:14415.11 batch_entropy:86.58 traj_lens:17.38 eval_time:1.87
# 16/04/2025 14:49:01 - INFO - logger - validation - iteration 100 : offline_loss:1170.69 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:1170.69 n_loss:0.00 tb_loss:1170.69 batch_entropy:56.55 traj_lens:15.28 eval_time:0.99
# 16/04/2025 14:49:03 - INFO - logger - validation - iteration 100 : offline_loss:1371.33 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:1371.33 n_loss:0.00 tb_loss:1371.33 batch_entropy:62.35 traj_lens:16.84 eval_time:1.16
# 16/04/2025 14:49:05 - INFO - logger - validation - iteration 100 : offline_loss:1234.15 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:1234.15 n_loss:0.00 tb_loss:1234.15 batch_entropy:58.29 traj_lens:15.81 eval_time:0.92
# 16/04/2025 14:49:08 - INFO - logger - validation - iteration 100 : offline_loss:1276.14 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:1276.14 n_loss:0.00 tb_loss:1276.14 batch_entropy:58.81 traj_lens:15.81 eval_time:0.94
# 16/04/2025 14:49:10 - INFO - logger - validation - iteration 100 : offline_loss:2232.50 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:2232.50 n_loss:0.00 tb_loss:2232.50 batch_entropy:60.30 traj_lens:15.28 eval_time:0.84
# 16/04/2025 14:49:12 - INFO - logger - validation - iteration 100 : offline_loss:1746.80 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:1746.80 n_loss:0.00 tb_loss:1746.80 batch_entropy:61.82 traj_lens:16.16 eval_time:0.97
# 16/04/2025 14:49:14 - INFO - logger - validation - iteration 100 : offline_loss:1363.47 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:1363.47 n_loss:0.00 tb_loss:1363.47 batch_entropy:59.38 traj_lens:16.16 eval_time:0.87
# 16/04/2025 14:49:16 - INFO - logger - validation - iteration 100 : offline_loss:1675.93 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:1675.93 n_loss:0.00 tb_loss:1675.93 batch_entropy:60.72 traj_lens:15.91 eval_time:1.08
# 16/04/2025 14:49:18 - INFO - logger - validation - iteration 100 : offline_loss:1198.11 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:1198.11 n_loss:0.00 tb_loss:1198.11 batch_entropy:59.99 traj_lens:16.28 eval_time:0.92
# 16/04/2025 14:49:19 - INFO - logger - validation - iteration 100 : offline_loss:1510.31 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:1510.31 n_loss:0.00 tb_loss:1510.31 batch_entropy:58.62 traj_lens:15.75 eval_time:0.87
# 16/04/2025 14:49:21 - INFO - logger - validation - iteration 100 : offline_loss:6074.68 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:6074.68 n_loss:0.00 tb_loss:6074.68 batch_entropy:68.63 traj_lens:15.72 eval_time:0.89
# 16/04/2025 14:49:23 - INFO - logger - validation - iteration 100 : offline_loss:1154.73 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:1154.73 n_loss:0.00 tb_loss:1154.73 batch_entropy:55.75 traj_lens:15.22 eval_time:0.87
# 16/04/2025 14:49:25 - INFO - logger - validation - iteration 100 : offline_loss:12998.27 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:12998.27 n_loss:0.00 tb_loss:12998.27 batch_entropy:83.73 traj_lens:16.39 eval_time:0.95
# 16/04/2025 14:49:36 - INFO - logger - iteration 101 : offline_loss:22407.23 online_loss:1505.18 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.18 loss:11956.20 n_loss:0.00 tb_loss:11956.20 batch_entropy:60.01 traj_lens:13.48 grad_norm:15795.68 grad_norm_clip:99.95 sampled_reward_avg:0.38 train_time:4.17 time_spent:50.25
# 16/04/2025 14:49:48 - INFO - logger - iteration 102 : offline_loss:1276.18 online_loss:823.73 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:5.25 loss:1049.96 n_loss:0.00 tb_loss:1049.96 batch_entropy:46.22 traj_lens:13.66 grad_norm:5845.88 grad_norm_clip:97.89 sampled_reward_avg:0.43 train_time:4.40 time_spent:11.66
# ...
# 16/04/2025 15:28:12 - INFO - logger - iteration 272 : offline_loss:261.39 online_loss:1168.73 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.88 loss:715.06 n_loss:0.00 tb_loss:715.06 batch_entropy:55.72 traj_lens:17.75 grad_norm:1539.14 grad_norm_clip:85.58 sampled_reward_avg:0.35 train_time:8.69 time_spent:21.03
# 16/04/2025 15:28:33 - INFO - logger - iteration 273 : offline_loss:462.64 online_loss:1491.15 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.86 loss:976.89 n_loss:0.00 tb_loss:976.89 batch_entropy:57.68 traj_lens:18.16 grad_norm:1728.11 grad_norm_clip:86.68 sampled_reward_avg:0.32 train_time:8.96 time_spent:21.30
# 16/04/2025 15:28:50 - INFO - logger - iteration 274 : offline_loss:1309.58 online_loss:1722.57 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.84 loss:1516.08 n_loss:0.00 tb_loss:1516.08 batch_entropy:50.92 traj_lens:15.44 grad_norm:2677.60 grad_norm_clip:90.65 sampled_reward_avg:0.30 train_time:7.03 time_spent:16.31
# 16/04/2025 15:29:06 - INFO - logger - iteration 275 : offline_loss:1952.83 online_loss:1508.52 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.82 loss:1730.68 n_loss:0.00 tb_loss:1730.68 batch_entropy:41.90 traj_lens:12.80 grad_norm:2508.31 grad_norm_clip:90.86 sampled_reward_avg:0.38 train_time:5.73 time_spent:16.04
# 16/04/2025 15:29:29 - INFO - logger - iteration 276 : offline_loss:348416.12 online_loss:2171.59 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.79 loss:175293.86 n_loss:0.00 tb_loss:175293.86 batch_entropy:123.65 traj_lens:19.67 grad_norm:39628.36 grad_norm_clip:100.70 sampled_reward_avg:0.17 train_time:11.64 time_spent:23.75
# 16/04/2025 15:29:46 - INFO - logger - iteration 277 : offline_loss:3498.20 online_loss:1781.59 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.77 loss:2639.90 n_loss:0.00 tb_loss:2639.90 batch_entropy:51.20 traj_lens:15.00 grad_norm:3327.65 grad_norm_clip:93.17 sampled_reward_avg:0.34 train_time:6.79 time_spent:16.76
# 16/04/2025 15:30:04 - INFO - logger - iteration 278 : offline_loss:314.22 online_loss:1455.83 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.76 loss:885.03 n_loss:0.00 tb_loss:885.03 batch_entropy:54.20 traj_lens:16.83 grad_norm:1588.46 grad_norm_clip:87.57 sampled_reward_avg:0.27 train_time:7.68 time_spent:17.73
# 16/04/2025 15:30:25 - INFO - logger - iteration 279 : offline_loss:331620.34 online_loss:1964.14 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.74 loss:166792.25 n_loss:0.00 tb_loss:166792.25 batch_entropy:101.37 traj_lens:16.78 grad_norm:24406.27 grad_norm_clip:100.56 sampled_reward_avg:0.27 train_time:9.18 time_spent:21.29
# 16/04/2025 15:30:46 - INFO - logger - iteration 280 : offline_loss:49394.18 online_loss:1606.20 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.74 loss:25500.19 n_loss:0.00 tb_loss:25500.19 batch_entropy:77.62 traj_lens:17.77 grad_norm:10099.64 grad_norm_clip:99.28 sampled_reward_avg:0.32 train_time:8.84 time_spent:20.41
# 16/04/2025 15:31:03 - INFO - logger - iteration 281 : offline_loss:280.48 online_loss:1742.39 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.74 loss:1011.44 n_loss:0.00 tb_loss:1011.44 batch_entropy:51.96 traj_lens:16.23 grad_norm:1630.71 grad_norm_clip:87.11 sampled_reward_avg:0.32 train_time:7.47 time_spent:17.82
# 16/04/2025 15:31:26 - INFO - logger - iteration 282 : offline_loss:326.94 online_loss:1481.78 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.74 loss:904.36 n_loss:0.00 tb_loss:904.36 batch_entropy:59.84 traj_lens:18.72 grad_norm:1323.62 grad_norm_clip:85.69 sampled_reward_avg:0.32 train_time:9.21 time_spent:22.25
# 16/04/2025 15:31:48 - INFO - logger - iteration 283 : offline_loss:802.68 online_loss:1380.15 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.74 loss:1091.41 n_loss:0.00 tb_loss:1091.41 batch_entropy:63.59 traj_lens:19.66 grad_norm:2144.12 grad_norm_clip:90.14 sampled_reward_avg:0.34 train_time:9.51 time_spent:22.44
# 16/04/2025 15:32:09 - INFO - logger - iteration 284 : offline_loss:454.06 online_loss:1485.76 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.76 loss:969.91 n_loss:0.00 tb_loss:969.91 batch_entropy:57.76 traj_lens:18.03 grad_norm:1944.34 grad_norm_clip:88.87 sampled_reward_avg:0.36 train_time:9.13 time_spent:20.77
# 16/04/2025 15:32:29 - INFO - logger - iteration 285 : offline_loss:359.36 online_loss:1121.11 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.78 loss:740.24 n_loss:0.00 tb_loss:740.24 batch_entropy:54.82 traj_lens:17.23 grad_norm:1540.97 grad_norm_clip:86.84 sampled_reward_avg:0.36 train_time:8.44 time_spent:19.93
# 16/04/2025 15:32:50 - INFO - logger - iteration 286 : offline_loss:15871.29 online_loss:1581.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.81 loss:8726.51 n_loss:0.00 tb_loss:8726.51 batch_entropy:70.91 traj_lens:18.83 grad_norm:6016.73 grad_norm_clip:98.33 sampled_reward_avg:0.26 train_time:9.60 time_spent:21.52
# 16/04/2025 15:33:12 - INFO - logger - iteration 287 : offline_loss:343.47 online_loss:1828.56 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.85 loss:1086.01 n_loss:0.00 tb_loss:1086.01 batch_entropy:60.65 traj_lens:18.88 grad_norm:1737.20 grad_norm_clip:89.17 sampled_reward_avg:0.21 train_time:9.53 time_spent:21.40
# 16/04/2025 15:33:28 - INFO - logger - iteration 288 : offline_loss:1538.30 online_loss:2029.48 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.87 loss:1783.89 n_loss:0.00 tb_loss:1783.89 batch_entropy:53.48 traj_lens:16.02 grad_norm:3348.86 grad_norm_clip:91.78 sampled_reward_avg:0.29 train_time:7.42 time_spent:16.72
# 16/04/2025 15:33:48 - INFO - logger - iteration 289 : offline_loss:259.23 online_loss:1460.77 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.88 loss:860.00 n_loss:0.00 tb_loss:860.00 batch_entropy:53.24 traj_lens:17.09 grad_norm:1281.52 grad_norm_clip:87.30 sampled_reward_avg:0.31 train_time:8.59 time_spent:19.79
# 16/04/2025 15:34:09 - INFO - logger - iteration 290 : offline_loss:332.28 online_loss:2155.86 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.88 loss:1244.07 n_loss:0.00 tb_loss:1244.07 batch_entropy:57.05 traj_lens:17.58 grad_norm:2147.73 grad_norm_clip:90.85 sampled_reward_avg:0.19 train_time:8.57 time_spent:20.73
# 16/04/2025 15:34:28 - INFO - logger - iteration 291 : offline_loss:816.81 online_loss:1364.15 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.87 loss:1090.48 n_loss:0.00 tb_loss:1090.48 batch_entropy:54.59 traj_lens:16.61 grad_norm:2139.83 grad_norm_clip:88.24 sampled_reward_avg:0.37 train_time:7.86 time_spent:19.15
# 16/04/2025 15:34:49 - INFO - logger - iteration 292 : offline_loss:350.54 online_loss:1622.87 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.88 loss:986.71 n_loss:0.00 tb_loss:986.71 batch_entropy:60.93 traj_lens:18.94 grad_norm:1650.61 grad_norm_clip:87.35 sampled_reward_avg:0.22 train_time:9.22 time_spent:21.14
# 16/04/2025 15:35:12 - INFO - logger - iteration 293 : offline_loss:349.74 online_loss:1918.68 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.87 loss:1134.21 n_loss:0.00 tb_loss:1134.21 batch_entropy:61.09 traj_lens:18.67 grad_norm:1709.11 grad_norm_clip:87.23 sampled_reward_avg:0.27 train_time:9.68 time_spent:22.66
# 16/04/2025 15:35:33 - INFO - logger - iteration 294 : offline_loss:314.08 online_loss:1399.21 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.85 loss:856.65 n_loss:0.00 tb_loss:856.65 batch_entropy:55.24 traj_lens:17.23 grad_norm:1513.92 grad_norm_clip:85.13 sampled_reward_avg:0.33 train_time:8.78 time_spent:20.73
# 16/04/2025 15:35:52 - INFO - logger - iteration 295 : offline_loss:1171.13 online_loss:1795.02 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.83 loss:1483.08 n_loss:0.00 tb_loss:1483.08 batch_entropy:56.51 traj_lens:17.03 grad_norm:1763.33 grad_norm_clip:88.04 sampled_reward_avg:0.25 train_time:8.18 time_spent:18.96
# 16/04/2025 15:36:10 - INFO - logger - iteration 296 : offline_loss:256.50 online_loss:1892.92 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.80 loss:1074.71 n_loss:0.00 tb_loss:1074.71 batch_entropy:51.11 traj_lens:16.36 grad_norm:1239.60 grad_norm_clip:85.60 sampled_reward_avg:0.30 train_time:7.55 time_spent:17.97
# 16/04/2025 15:36:28 - INFO - logger - iteration 297 : offline_loss:5538.99 online_loss:1814.62 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.77 loss:3676.81 n_loss:0.00 tb_loss:3676.81 batch_entropy:59.91 traj_lens:16.47 grad_norm:3551.53 grad_norm_clip:94.70 sampled_reward_avg:0.28 train_time:7.80 time_spent:18.02
# 16/04/2025 15:36:49 - INFO - logger - iteration 298 : offline_loss:2098.51 online_loss:2342.48 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.75 loss:2220.49 n_loss:0.00 tb_loss:2220.49 batch_entropy:59.17 traj_lens:17.48 grad_norm:2510.83 grad_norm_clip:89.32 sampled_reward_avg:0.27 train_time:8.72 time_spent:20.98
# 16/04/2025 15:37:10 - INFO - logger - iteration 299 : offline_loss:441.92 online_loss:1607.17 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.72 loss:1024.54 n_loss:0.00 tb_loss:1024.54 batch_entropy:62.99 traj_lens:19.39 grad_norm:1845.98 grad_norm_clip:86.01 sampled_reward_avg:0.24 train_time:9.63 time_spent:21.40
# 16/04/2025 15:37:29 - INFO - logger - iteration 300 : offline_loss:6994.50 online_loss:1995.74 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.69 loss:4495.12 n_loss:0.00 tb_loss:4495.12 batch_entropy:63.23 traj_lens:17.44 grad_norm:3725.67 grad_norm_clip:94.89 sampled_reward_avg:0.33 train_time:8.83 time_spent:19.56
# 16/04/2025 15:37:47 - INFO - logger - validation - iteration 300 : offline_loss:340.09 online_loss:1487.17 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.67 loss:913.63 n_loss:0.00 tb_loss:913.63 batch_entropy:59.72 traj_lens:18.77 sampled_reward_avg:0.31 eval_time:3.24
# 16/04/2025 15:37:51 - INFO - logger - validation - iteration 300 : offline_loss:12023.37 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.67 loss:12023.37 n_loss:0.00 tb_loss:12023.37 batch_entropy:74.77 traj_lens:17.38 eval_time:1.42
# 16/04/2025 15:37:53 - INFO - logger - validation - iteration 300 : offline_loss:257.72 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.67 loss:257.72 n_loss:0.00 tb_loss:257.72 batch_entropy:46.15 traj_lens:15.28 eval_time:1.14
# 16/04/2025 15:37:56 - INFO - logger - validation - iteration 300 : offline_loss:339.80 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.67 loss:339.80 n_loss:0.00 tb_loss:339.80 batch_entropy:51.21 traj_lens:16.84 eval_time:1.22
# 16/04/2025 15:37:58 - INFO - logger - validation - iteration 300 : offline_loss:286.50 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.67 loss:286.50 n_loss:0.00 tb_loss:286.50 batch_entropy:47.95 traj_lens:15.81 eval_time:1.16
# 16/04/2025 15:38:01 - INFO - logger - validation - iteration 300 : offline_loss:321.20 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.67 loss:321.20 n_loss:0.00 tb_loss:321.20 batch_entropy:49.23 traj_lens:15.81 eval_time:1.13
# 16/04/2025 15:38:03 - INFO - logger - validation - iteration 300 : offline_loss:1049.14 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.67 loss:1049.14 n_loss:0.00 tb_loss:1049.14 batch_entropy:50.68 traj_lens:15.34 eval_time:1.11
# 16/04/2025 15:38:06 - INFO - logger - validation - iteration 300 : offline_loss:643.76 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.67 loss:643.76 n_loss:0.00 tb_loss:643.76 batch_entropy:51.23 traj_lens:16.16 eval_time:1.21
# 16/04/2025 15:38:08 - INFO - logger - validation - iteration 300 : offline_loss:342.87 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.67 loss:342.87 n_loss:0.00 tb_loss:342.87 batch_entropy:48.55 traj_lens:16.16 eval_time:1.18
# 16/04/2025 15:38:10 - INFO - logger - validation - iteration 300 : offline_loss:618.96 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.67 loss:618.96 n_loss:0.00 tb_loss:618.96 batch_entropy:49.79 traj_lens:15.91 eval_time:1.22
# 16/04/2025 15:38:13 - INFO - logger - validation - iteration 300 : offline_loss:314.54 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.67 loss:314.54 n_loss:0.00 tb_loss:314.54 batch_entropy:49.47 traj_lens:16.28 eval_time:1.21
# 16/04/2025 15:38:16 - INFO - logger - validation - iteration 300 : offline_loss:503.98 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.67 loss:503.98 n_loss:0.00 tb_loss:503.98 batch_entropy:48.51 traj_lens:15.75 eval_time:1.10
# 16/04/2025 15:38:18 - INFO - logger - validation - iteration 300 : offline_loss:4610.36 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.67 loss:4610.36 n_loss:0.00 tb_loss:4610.36 batch_entropy:58.60 traj_lens:15.72 eval_time:1.19
# 16/04/2025 15:38:21 - INFO - logger - validation - iteration 300 : offline_loss:269.10 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.67 loss:269.10 n_loss:0.00 tb_loss:269.10 batch_entropy:45.56 traj_lens:15.22 eval_time:1.08
# 16/04/2025 15:38:23 - INFO - logger - validation - iteration 300 : offline_loss:10925.64 online_loss:0.00 reward_loss:0.00 invalid_trajectories:0.00 invalid_logprob:0.00 invalid_losses:0.00 backward_vs_unif:0.00 logZ:12.67 loss:10925.64 n_loss:0.00 tb_loss:10925.64 batch_entropy:73.49 traj_lens:16.39 eval_time:1.25

# %%
from rdkit.Chem.Draw import MolsToGridImage, MolToImage

# %%
(335.69 + 153.25)/2
# Out:
# 244.47

# %%
# Generate molecules
trajs = trial.algo.create_training_data_from_own_samples(trial.model, 25)
objs = [trial.ctx.graph_to_obj(i['result']) for i in trajs]
obj_props, is_valid = trial.task.compute_obj_properties(objs)
cond_info = trial.task.sample_conditional_information(len(obj_props), 1)
log_rewards = trial.task.cond_info_to_logreward(cond_info, obj_props)


MolsToGridImage(objs[:25], molsPerRow=5, subImgSize=(200, 120))#, legends=[f'reward: {r.exp().item():.2f}' for r in log_rewards[:25]])

# %%
objs[3]

# %%
#ea.Tags()

# %%
from gflownet.config import init_empty, Config
cfg = init_empty(Config())
from tensorboard.backend.event_processing import event_accumulator

cfg.log_dir = config.log_dir
ea = event_accumulator.EventAccumulator(cfg.log_dir)
ea.Reload()

import matplotlib.pyplot as pp
f, ax = pp.subplots(3, 2, figsize=(4*3,3))
ax[0,0].plot([i.value for i in ea.Scalars('train_loss')])
ax[0,0].set_yscale('log')
ax[0,0].set_ylabel('TB loss')
ax[0,1].plot([i.value for i in ea.Scalars('train_sampled_reward_avg')])
ax[0,1].set_ylabel('Average reward')
#ax[0,2].plot([i.value for i in ea.Scalars('train_logZ')])
#ax[0,2].set_ylabel('Predicted logZ')
ax[1,0].plot([i.value for i in ea.Scalars('train_online_loss')])
ax[1,0].set_yscale('log')
ax[1,0].set_ylabel('Online loss')
ax[1,1].plot([i.value for i in ea.Scalars('train_offline_loss')])
ax[1,1].set_yscale('log')
ax[1,1].set_ylabel('Offline loss')
ax[2,0].plot([i.value for i in ea.Scalars('valid_online_loss')])
ax[2,0].set_yscale('log')
ax[2,0].set_ylabel('Validation online loss')
ax[2,1].plot([i.value for i in ea.Scalars('valid_offline_loss')])
ax[2,1].set_yscale('log')
ax[2,1].set_ylabel('Validation offline loss')
pp.tight_layout()

# %%
max([i.value for i in ea.Scalars('train_sampled_reward_avg')])
# Out:
# 0.7858443856239319

# %%
cfg.log_dir+"/train/"
# Out:
# './logs/dataload_2/train'

# %%
# !dir ./logs/dataload_2/train/
# Out:
# Parameter format not correct - "logs".

# %%
import sqlite3
import pandas as pd
from rdkit.Chem.Draw import MolsToGridImage, MolToImage

# %%
conn = sqlite3.connect(f"{cfg.log_dir}/train/generated_objs_0.db")

# %%
df = pd.read_sql_query("SELECT * FROM results", conn)

# %%
import numpy as np

# %%
idx_list = sorted([j*32 -i -1  for j in [50,100,150,200,300] for i in range(5)])

# %%
choosendf = df.iloc[idx_list]

# %%
top_rewards = df.sort_values(by='r', ascending=False).head(25)

# %%
# Generate molecules
objs = [Chem.MolFromSmiles(smiles) for smiles in top_rewards["smi"]]
rewards = top_rewards["r"]


MolsToGridImage(objs[:25], molsPerRow=5, subImgSize=(200, 120), legends=[f'reward: {r:.2f}' for r in rewards[:25]])

# %%
df['iteration'] = df.index // 32

# Compute mean of desired columns per iteration
# Example: mean reward per iteration
# Replace 'reward' with your actual column name
mean_per_iter = df.groupby('iteration')['r'].mean()
mean_per_iter
# Out:
# iteration
# 0      0.312337
# 1      0.308062
# 2      0.272129
# 3      0.271025
# 4      0.321098
#          ...
# 295    0.295226
# 296    0.279961
# 297    0.269994
# 298    0.241168
# 299    0.328628
# Name: r, Length: 300, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(mean_per_iter)

# %%
from rdkit import Chem

# %%
# Generate molecules
objs = [Chem.MolFromSmiles(smiles) for smiles in choosendf["smi"]]
rewards = choosendf["r"]


MolsToGridImage(objs[:25], molsPerRow=5, subImgSize=(200, 120), legends=[f'reward: {r:.2f}' for r in rewards[:25]])

# %% [markdown]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 23
#      18 config.overwrite_existing_exp=True
#      22 trial = ScentTrainer(config)
# ---> 23 trial.run()
#      24 save_run(trial)
#
# File c:\Users\paulj\Desktop\Master\venv\lib\site-packages\gflownet\trainer.py:271, in GFNTrainer.run(self, logger)
#     269 logger.info("Starting training")
#     270 start_time = time.time()
# --> 271 for it, batch in zip(range(start, 1 + num_training_steps), cycle(train_dl)):
#     272     # the memory fragmentation or allocation keeps growing, how often should we clean up?
#     273     # is changing the allocation strategy helpful?
#     275     if it % 1024 == 0:
#     276         gc.collect()
#
# File c:\Users\paulj\Desktop\Master\venv\lib\site-packages\gflownet\trainer.py:377, in cycle(it)
#     375 def cycle(it):
#     376     while True:
# --> 377         for i in it:
#     378             yield i
#
# File c:\Users\paulj\Desktop\Master\venv\lib\site-packages\torch\utils\data\dataloader.py:708, in _BaseDataLoaderIter.__next__(self)
#     705 if self._sampler_iter is None:
#     706     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707     self._reset()  # type: ignore[call-arg]
# --> 708 data = self._next_data()
#     709 self._num_yielded += 1
#     710 if (
#     711     self._dataset_kind == _DatasetKind.Iterable
#     712     and self._IterableDataset_len_called is not None
#     713     and self._num_yielded > self._IterableDataset_len_called
#     714 ):
#
# File c:\Users\paulj\Desktop\Master\venv\lib\site-packages\torch\utils\data\dataloader.py:764, in _SingleProcessDataLoaderIter._next_data(self)
#     762 def _next_data(self):
#     763     index = self._next_index()  # may raise StopIteration
# --> 764     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     765     if self._pin_memory:
#     766         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\paulj\Desktop\Master\venv\lib\site-packages\torch\utils\data\_utils\fetch.py:42, in _IterableDatasetFetcher.fetch(self, possibly_batched_index)
#      40         raise StopIteration
#      41 else:
# ---> 42     data = next(self.dataset_iter)
#      43 return self.collate_fn(data)
#
# File c:\Users\paulj\Desktop\Master\venv\lib\site-packages\gflownet\data\data_source.py:80, in DataSource.__iter__(self)
#      78 for d in batch_infos:
#      79     batch_info.update(d)
# ---> 80 yield self.create_batch(trajs, batch_info)
#
# File c:\Users\paulj\Desktop\Master\venv\lib\site-packages\gflownet\data\data_source.py:220, in DataSource.create_batch(self, trajs, batch_info)
#     218 ci = torch.stack([t["cond_info"]["encoding"] for t in trajs])
#     219 log_rewards = torch.stack([t["log_reward"] for t in trajs])
# --> 220 batch = self.algo.construct_batch(trajs, ci, log_rewards)
#     221 batch.num_online = sum(t.get("is_online", 0) for t in trajs)
#     222 batch.num_offline = len(trajs) - batch.num_online
#
# File c:\Users\paulj\Desktop\Master\venv\lib\site-packages\gflownet\algo\trajectory_balance.py:311, in TrajectoryBalance.construct_batch(self, trajs, cond_info, log_rewards)
#     307     actions = [
#     308         self.ctx.GraphAction_to_ActionIndex(g, i[1]) for g, tj in zip(torch_graphs, trajs) for i in tj["traj"]
#     309     ]
#     310 else:
# --> 311     torch_graphs = [self.ctx.graph_to_Data(i[0]) for tj in trajs for i in tj["traj"]]
#     312     actions = [
#     313         self.ctx.GraphAction_to_ActionIndex(g, a)
#     314         for g, a in zip(torch_graphs, [i[1] for tj in trajs for i in tj["traj"]])
#     315     ]
#     316 batch = self.ctx.collate(torch_graphs)
#
# File c:\Users\paulj\Desktop\Master\venv\lib\site-packages\gflownet\algo\trajectory_balance.py:311, in <listcomp>(.0)
#     307     actions = [
#     308         self.ctx.GraphAction_to_ActionIndex(g, i[1]) for g, tj in zip(torch_graphs, trajs) for i in tj["traj"]
#     309     ]
#     310 else:
# --> 311     torch_graphs = [self.ctx.graph_to_Data(i[0]) for tj in trajs for i in tj["traj"]]
#     312     actions = [
#     313         self.ctx.GraphAction_to_ActionIndex(g, a)
#     314         for g, a in zip(torch_graphs, [i[1] for tj in trajs for i in tj["traj"]])
#     315     ]
#     316 batch = self.ctx.collate(torch_graphs)
#
# File c:\Users\paulj\Desktop\Master\venv\lib\site-packages\gflownet\envs\mol_building_env.py:280, in MolBuildingEnvContext.graph_to_Data(self, g)
#     277     remove_node_mask[i] = 1
#     278 for k, sl in zip(self.atom_attrs, self.atom_attr_slice):
#     279     # idx > 0 means that the attribute is not the default value
# --> 280     idx = self.atom_attr_values[k].index(ad[k]) if k in ad else 0
#     281     x[i, sl + idx] = 1
#     282     if k == "v":
#
# ValueError: 1 is not in list
